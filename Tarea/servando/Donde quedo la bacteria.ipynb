# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
x0=0
M=10000
N=1000 #unidades de tiempo
data=np.random.choice(np.array([1,-1]),N)
T,X=np.meshgrid(np.arange(0,N),np.arange(0,M))

# %%
db=np.zeros((M,N))
for i in range(M):
    db[i,:]=np.random.choice(np.array([1,-1]),N)
plt.scatter(T,db)

# %% [markdown]
# ## Promedio

# %%
Int=np.zeros((M,N))
dist=np.zeros((M,N))
for i in range(0,N):
    Int[:,i]=np.sum(db[:,0:i],1)
    dist[:,i]=np.sum(abs(db[:,0:i]),1)
#plt.scatter(T[0,:],np.mean(db,0))

# %%
plt.scatter(T,Int,s=1/5,alpha=1/1000)

# %%
np.mean(abs(Int[:,-1]))
# Out:
# 25.1196
